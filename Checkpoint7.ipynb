# %%
import requests as re
from bs4 import BeautifulSoup

# %%
title = input("""search: #enter the title you want to search about\n if there is a space use _ instead: """).capitalize()

page = re.get(f"https://en.wikipedia.org/wiki/{title}")
# Out:
# search: #enter the title you want to search about
#  if there is a space use _ instead: youssif

# %%
def main(page):
    
    src = page.content
    soup = BeautifulSoup(src, "lxml")
    content_container = soup.find_all("div", {"class": "mw-content-container"})
    page_title = soup.find_all("span", {"class": "mw-page-title-main"})
    info_container = soup.find_all("div", {"class": "vector-body"}).text()
    print(info_container)

# %%
main(page)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 main(page)
#
# Cell In[62], line 7, in main(page)
#       5 content_container = soup.find_all("div", {"class": "mw-content-container"})
#       6 page_title = soup.find_all("span", {"class": "mw-page-title-main"})
# ----> 7 info_container = soup.find_all("div", {"class": "vector-body"}).text()
#       8 print(info_container)
#
# File ~\anaconda3\lib\site-packages\bs4\element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# ...

# %%
pip install wikipedia
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wikipedia as wiki
import os

# %%
def home_screen():
    print("-"*20 + "Wikipedia" + "-"*20)
    print("type back to go back")
    print("type exit to close programm")
    print("-"*49)
        
   
    
def leave(choose = "exit"):
    
        if choose == "exit":
            return False
        else:
            return True
        
    
    
    
    
    
def wikipedia():
    play = True
    while play:
        home_screen()
        article = input("search: ")
        
        ls = wiki.search(article)
        ls = [x.lower() for x in ls]
        print(ls)
        choose = input("choose an option ").lower()
        if choose.lower() == "exit":
            print("thanks for coming by!")
            play = leave()
        
        
        elif choose in ls:
            print(wiki.page(choose).content)
        
            
        elif choose not in ls:
            print("try again")
            choose = input("choose an option ")
           
        play = leave()

# %%
wikipedia()
# Out:
# --------------------Wikipedia--------------------
# type back to go back
# type exit to close programm
# -------------------------------------------------
# search: youssif
# ['yusuf', 'youssif (burn victim)', 'ahmed youssif', 'hassan youssef (actor)', 'yusuf salman yusuf', 'ali tawfik youssif', 'youssef hassan', 'yousuf al-thunayan', 'mohamed youssef (basketball)', 'ibrahim youssef']
# choose an option yusuf
# Yusuf (Arabic: يوسف Yūsuf) is a male name meaning "God increases" (in piety, power and influence). It is the Arabic equivalent of the Hebrew name Yosef and the English name Joseph. It is widely used in many parts of the world by Arabs of all Abrahamic religions, including Middle Eastern Jews, Arab Christians, and Muslims.
# It is also transliterated in many ways, including Yousef, Yousif, Youssef, Youssif, Yousuf and Yusef.
#
#
# == Given name ==
#
#
# === Yousaf ===
#
# Yousaf Ali Khan, British film director
# ...
